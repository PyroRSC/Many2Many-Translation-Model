# %% [markdown]
# ### Machine Translation

# %% [markdown]
# Login hugging face

# %%
from huggingface_hub import login
login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# ### Configs

# %%
from transformers import ( BitsAndBytesConfig, M2M100Tokenizer, AutoModelForSeq2SeqLM, DataCollatorForSeq2Seq)
import torch
import pandas as pd
from peft import LoraConfig, get_peft_model

LANGONE_CODE = "tl"
LANGTWO_CODE = "bcl"
CORPORA_PATH = "dataset/tl-bcl-corpora.csv"
MODEL_NAME = "models/extended_lang_m2m100_1.2B"
# configs
# quantization config
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    # use nf4 instead of fp4 for quantization performance
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16
)

lora_config = LoraConfig(
    r=8,
    lora_alpha=32,
    target_modules=["q_proj", "v_proj"],
    lora_dropout=0.05,
    bias="none",
    task_type="SEQ_2_SEQ_LM",
)

# %% [markdown]
# ### Initializing Model
#
# initialize model for quantization and LORA for lower VRAM consumption

# %%
# model config
from peft import PeftModel

model = AutoModelForSeq2SeqLM.from_pretrained(
    MODEL_NAME,
    quantization_config=bnb_config
)

model = get_peft_model(model,lora_config)
model.print_trainable_parameters()
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# trainable params: 2,359,296 || all params: 1,265,134,592 || trainable%: 0.1865

# %% [markdown]
# ### Initialized Tokenizer and Import Dataset
# Lets finetune the model to support cebuano to english

# %%
import datasets
TOKENIZER = "tokenizers/extended_m2m100tokenizer"
tokenizer = M2M100Tokenizer.from_pretrained(TOKENIZER,src_lang=LANGONE_CODE)
tokenizer.tgt_lang = LANGTWO_CODE
df = pd.read_csv(CORPORA_PATH)
if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token
print(df)
# Out:
#        Unnamed: 0                                     language1_text  \
# 0          249283  Sa kapinonan, kan lalangon nin Dios an kalangi...
# 1          249284  an kinaban mayo nin ano man na porma saka laog...
# 2          249285  Nagboot an Dios, "Magkaigwa nin liwanag," asin...
# 3          249286  Nahiling nin Dios na marahay an liwanag. Isinu...
# 4          249287  dangan inapod niyang "Aldaw" an liwanag, asin ...
# ...           ...                                                ...
# 28181      277464  "Madya!" an sabi kan Espiritu asin kan Nobya. ...
# 28182      277465  Ako, si Juan, nagpapatanid sa gabos na nakakad...
# 28183      277466  An siisay man na mag-ina nin anoman sa mga pro...
# 28184      277467  An nagsasaksi kan gabos na ini nagsasabi, "Tot...
# 28185      277468  Mapasagabos logod an biyaya ni Jesus na Kagura...
#
#                                           language2_text
# 0      Nang pasimula, nilikha ng Diyos ang langit at ...
# 1      Ang lupa ay walang anyo at walang laman, at bi...
# 2      At sinabi ng Diyos, "Magkaroon ng liwanag," at...
# 3      Nakita ng Diyos na ang liwanag ay mabuti, at i...
# 4      Tinawag ng Diyos ang liwanag na Araw, at ang k...
# ...                                                  ...
# 28181  Ang Espiritu at ang babaing ikakasal ay nagsas...
# 28182  Aking binabalaan ang bawat taong nakikinig sa ...
# 28183  at kung ang sinuman ay mag-alis sa mga salita ...
# 28184  Ang nagpapatotoo sa mga bagay na ito ay nagsas...
# 28185  Ang biyaya ng Panginoong Jesus ay mapasa mga b...
#
# [28186 rows x 3 columns]

# %%
def preprocess(batch):
    
    model_inputs = tokenizer(
        batch["language1_text"],
        truncation=True,
        padding="max_length",
        max_length=128,
    )
    labels = tokenizer(
        batch["language2_text"],
        truncation=True,
        padding="max_length",
        max_length=128,
    )
    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

train_df = df.sample(frac=0.8, random_state=42)
eval_df = df[~df.index.isin(train_df.index)]
train_df = train_df.reset_index(drop=True)

training_dataset = datasets.Dataset.from_pandas(train_df)
evaluation_dataset = datasets.Dataset.from_pandas(eval_df)
train_dataset_processed = training_dataset.map(preprocess, batched=True, remove_columns=['language1_text', 'language2_text','Unnamed: 0'])
eval_dataset_processed = evaluation_dataset.map(preprocess, batched=True, remove_columns=['language1_text', 'language2_text','Unnamed: 0'])
# Out:
# Map:   0%|          | 0/22549 [00:00<?, ? examples/s]
# Map:   0%|          | 0/5637 [00:00<?, ? examples/s]

# %% [markdown]
# ### Training

# %%
from transformers import Seq2SeqTrainingArguments

training_args = Seq2SeqTrainingArguments(
    output_dir=MODEL_NAME,
    per_device_train_batch_size=4,
    per_device_eval_batch_size=4,
    num_train_epochs=3,
    learning_rate=5e-5,
    logging_steps=1000,
    save_steps=2000,
    save_total_limit=2,
    predict_with_generate=True,
    bf16=True,
    report_to="none"
)

# %%
from transformers import Seq2SeqTrainer
import numpy as np
import evaluate

sacrebleu = evaluate.load("sacrebleu")


def postprocess_text(preds, labels):
    preds = [pred.strip() for pred in preds]
    labels = [[label.strip()] for label in labels]
    return preds, labels


def compute_metrics(eval_preds):
    preds, labels = eval_preds
    if isinstance(preds, tuple):
        preds = preds[0]

    decoded_preds = tokenizer.batch_decode(preds, skip_special_tokens=True)
    labels = np.where(labels != -100, labels, tokenizer.pad_token_id)

    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)
    decoded_preds, decoded_labels = postprocess_text(decoded_preds, decoded_labels)

    result = sacrebleu.compute(predictions=decoded_preds, references=decoded_labels)
    result = {"bleu": result["score"]}

    prediction_lens = [np.count_nonzero(pred != tokenizer.pad_token_id) for pred in preds]

    result["gen_len"] = np.mean(prediction_lens)
    result = {k: round(v, 4) for k, v in result.items()}

    return result

data_collator = DataCollatorForSeq2Seq(
    tokenizer=tokenizer,
    model=model,
    padding="longest",  # pads to the longest sequence in the batch
    return_tensors="pt" # converts lists -> PyTorch tensors
)

trainer = Seq2SeqTrainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset_processed,
    eval_dataset=eval_dataset_processed,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics,
    data_collator=data_collator
)
# Out:
# /tmp/ipykernel_9/1568665726.py:42: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Seq2SeqTrainer.__init__`. Use `processing_class` instead.
#   trainer = Seq2SeqTrainer(

# %%
trainer.evaluate()
# Out:
#     <div>
#
#       <progress value='1410' max='1410' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1410/1410 1:05:28]
#     </div>
# That's 100 lines that end in a tokenized period ('.')
# It looks like you forgot to detokenize your test data, which may hurt your score.
# If you insist your data is detokenized, or don't care, you can suppress this message with the `force` parameter.
# {'eval_loss': 12.126548767089844,
#  'eval_model_preparation_time': 0.0048,
#  'eval_bleu': 0.0234,
#  'eval_gen_len': 43.0685,
#  'eval_runtime': 4018.1002,
#  'eval_samples_per_second': 1.403,
#  'eval_steps_per_second': 0.351}
